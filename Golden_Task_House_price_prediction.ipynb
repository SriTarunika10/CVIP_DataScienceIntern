# %% [markdown]
# **Import all necessary libaries**
#
# ---

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **Read the CSV file**

# %%
df=pd.read_csv("/content/data.csv")

# %%
df
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 0         7912     1.5           0     0          3        1340
# 1         9050     2.0           0     4          5        3370
# 2        11947     1.0           0     0          4        1930
# 3         8030     1.0           0     0          4        1000
# 4        10500     1.0           0     0          4        1140
# ...        ...     ...         ...   ...        ...         ...
# 4595      6360     1.0           0     0          4        1510
# 4596      7573     2.0           0     0          3        1460
# 4597      7014     2.0           0     0          3        3010
# 4598      6630     1.0           0     0          3        1070
# 4599      8102     2.0           0     0          4        1490
#
#       sqft_basement  yr_built  yr_renovated                    street  \
# 0                 0      1955          2005      18810 Densmore Ave N
# 1               280      1921             0           709 W Blaine St
# 2                 0      1966             0  26206-26214 143rd Ave SE
# 3              1000      1963             0           857 170th Pl NE
# 4               800      1976          1992         9105 170th Ave NE
# ...             ...       ...           ...                       ...
# 4595              0      1954          1979            501 N 143rd St
# 4596              0      1983          2009          14855 SE 10th Pl
# 4597              0      2009             0          759 Ilwaco Pl NE
# 4598           1020      1974             0         5148 S Creston St
# 4599              0      1990             0         18717 SE 258th St
#
#            city  statezip country
# 0     Shoreline  WA 98133     USA
# 1       Seattle  WA 98119     USA
# 2          Kent  WA 98042     USA
# 3      Bellevue  WA 98008     USA
# 4       Redmond  WA 98052     USA
# ...         ...       ...     ...
# 4595    Seattle  WA 98133     USA
# 4596   Bellevue  WA 98007     USA
# 4597     Renton  WA 98059     USA
# 4598    Seattle  WA 98178     USA
# 4599  Covington  WA 98042     USA
#
# [4600 rows x 18 columns]

# %%
#head
df.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
#    yr_renovated                    street       city  statezip country
# 0          2005      18810 Densmore Ave N  Shoreline  WA 98133     USA
# 1             0           709 W Blaine St    Seattle  WA 98119     USA
# 2             0  26206-26214 143rd Ave SE       Kent  WA 98042     USA
# 3             0           857 170th Pl NE   Bellevue  WA 98008     USA
# 4          1992         9105 170th Ave NE    Redmond  WA 98052     USA

# %%
#tail
df.tail()
# Out:
#                      date          price  bedrooms  bathrooms  sqft_living  \
# 4595  2014-07-09 00:00:00  308166.666667       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  534333.333333       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  416904.166667       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  203400.000000       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  220600.000000       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 4595      6360     1.0           0     0          4        1510
# 4596      7573     2.0           0     0          3        1460
# 4597      7014     2.0           0     0          3        3010
# 4598      6630     1.0           0     0          3        1070
# 4599      8102     2.0           0     0          4        1490
#
#       sqft_basement  yr_built  yr_renovated             street       city  \
# 4595              0      1954          1979     501 N 143rd St    Seattle
# 4596              0      1983          2009   14855 SE 10th Pl   Bellevue
# 4597              0      2009             0   759 Ilwaco Pl NE     Renton
# 4598           1020      1974             0  5148 S Creston St    Seattle
# 4599              0      1990             0  18717 SE 258th St  Covington
#
#       statezip country
# 4595  WA 98133     USA
# 4596  WA 98007     USA
# 4597  WA 98059     USA
# 4598  WA 98178     USA
# 4599  WA 98042     USA

# %%
#info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   float64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   object
#  16  statezip       4600 non-null   object
#  17  country        4600 non-null   object
# dtypes: float64(4), int64(9), object(5)
# memory usage: 647.0+ KB

# %%
#describe
df.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.600000e+03  4600.000000  4600.000000   4600.000000  4.600000e+03
# mean   5.519630e+05     3.400870     2.160815   2139.346957  1.485252e+04
# std    5.638347e+05     0.908848     0.783781    963.206916  3.588444e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.228750e+05     3.000000     1.750000   1460.000000  5.000750e+03
# 50%    4.609435e+05     3.000000     2.250000   1980.000000  7.683000e+03
# 75%    6.549625e+05     4.000000     2.500000   2620.000000  1.100125e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4600.000000  4600.000000  4600.000000  4600.000000  4600.000000
# mean      1.512065     0.007174     0.240652     3.451739  1827.265435
# std       0.538288     0.084404     0.778405     0.677230   862.168977
# min       1.000000     0.000000     0.000000     1.000000   370.000000
# 25%       1.000000     0.000000     0.000000     3.000000  1190.000000
# 50%       1.500000     0.000000     0.000000     3.000000  1590.000000
# 75%       2.000000     0.000000     0.000000     4.000000  2300.000000
# max       3.500000     1.000000     4.000000     5.000000  9410.000000
#
#        sqft_basement     yr_built  yr_renovated
# count    4600.000000  4600.000000   4600.000000
# mean      312.081522  1970.786304    808.608261
# std       464.137228    29.731848    979.414536
# min         0.000000  1900.000000      0.000000
# 25%         0.000000  1951.000000      0.000000
# 50%         0.000000  1976.000000      0.000000
# 75%       610.000000  1997.000000   1999.000000
# max      4820.000000  2014.000000   2014.000000

# %%
#describe
df.shape
# Out:
# (4600, 18)

# %%
# number of rows and columns
print("Number of rows:   ",df.shape[0])
print("Number of columns:",df.shape[1])
# Out:
# Number of rows:    4600
# Number of columns: 18

# %%
#Null values
df.isnull()
# Out:
#        date  price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0     False  False     False      False        False     False   False
# 1     False  False     False      False        False     False   False
# 2     False  False     False      False        False     False   False
# 3     False  False     False      False        False     False   False
# 4     False  False     False      False        False     False   False
# ...     ...    ...       ...        ...          ...       ...     ...
# 4595  False  False     False      False        False     False   False
# 4596  False  False     False      False        False     False   False
# 4597  False  False     False      False        False     False   False
# 4598  False  False     False      False        False     False   False
# 4599  False  False     False      False        False     False   False
#
#       waterfront   view  condition  sqft_above  sqft_basement  yr_built  \
# 0          False  False      False       False          False     False
# 1          False  False      False       False          False     False
# 2          False  False      False       False          False     False
# 3          False  False      False       False          False     False
# 4          False  False      False       False          False     False
# ...          ...    ...        ...         ...            ...       ...
# 4595       False  False      False       False          False     False
# 4596       False  False      False       False          False     False
# 4597       False  False      False       False          False     False
# 4598       False  False      False       False          False     False
# 4599       False  False      False       False          False     False
#
#       yr_renovated  street   city  statezip  country
# 0            False   False  False     False    False
# 1            False   False  False     False    False
# 2            False   False  False     False    False
# 3            False   False  False     False    False
# 4            False   False  False     False    False
# ...            ...     ...    ...       ...      ...
# 4595         False   False  False     False    False
# 4596         False   False  False     False    False
# 4597         False   False  False     False    False
# 4598         False   False  False     False    False
# 4599         False   False  False     False    False
#
# [4600 rows x 18 columns]

# %%
#displaying the total null values
df.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %%
#displaying the columns
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'street', 'city',
#        'statezip', 'country'],
#       dtype='object')

# %%
df.rename(columns={"yr_built":"year_built"},inplace=True)

# %%
df.groupby(by=["date"]).mean()
# Out:
# <ipython-input-18-ea5dec7f2de7>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(by=["date"]).mean()
#                              price  bedrooms  bathrooms  sqft_living  \
# date
# 2014-05-02 00:00:00  525538.475480  3.402985   2.138060  2102.835821
# 2014-05-03 00:00:00  466970.000000  3.000000   1.812500  1620.000000
# 2014-05-04 00:00:00  576690.000000  3.200000   2.400000  2508.000000
# 2014-05-05 00:00:00  586067.724206  3.523810   2.193452  2257.845238
# 2014-05-06 00:00:00  517471.196787  3.493976   2.171687  2102.168675
# ...                            ...       ...        ...          ...
# 2014-07-06 00:00:00  709930.000000  3.000000   2.000000  2210.000000
# 2014-07-07 00:00:00  527370.791165  3.301205   2.066265  2053.819277
# 2014-07-08 00:00:00  540899.275826  3.299213   2.200787  2225.692913
# 2014-07-09 00:00:00  565763.193821  3.528926   2.198347  2284.239669
# 2014-07-10 00:00:00  570716.322581  3.548387   2.241935  2334.193548
#
#                          sqft_lot    floors  waterfront      view  condition  \
# date
# 2014-05-02 00:00:00  15640.477612  1.462687    0.000000  0.223881   3.447761
# 2014-05-03 00:00:00   8901.000000  1.250000    0.000000  0.000000   3.500000
# 2014-05-04 00:00:00   7563.000000  1.400000    0.000000  0.400000   3.400000
# 2014-05-05 00:00:00  17966.309524  1.565476    0.000000  0.202381   3.440476
# 2014-05-06 00:00:00  12127.662651  1.457831    0.000000  0.120482   3.349398
# ...                           ...       ...         ...       ...        ...
# 2014-07-06 00:00:00   5440.000000  1.166667    0.000000  1.333333   3.666667
# 2014-07-07 00:00:00  16340.481928  1.620482    0.000000  0.144578   3.530120
# 2014-07-08 00:00:00  15754.590551  1.515748    0.015748  0.228346   3.346457
# 2014-07-09 00:00:00  13812.024793  1.516529    0.000000  0.173554   3.528926
# 2014-07-10 00:00:00  21040.258065  1.532258    0.000000  0.129032   3.580645
#
#                       sqft_above  sqft_basement   year_built  yr_renovated
# date
# 2014-05-02 00:00:00  1819.850746     282.985075  1972.850746    891.208955
# 2014-05-03 00:00:00  1490.000000     130.000000  1978.750000    478.000000
# 2014-05-04 00:00:00  1878.000000     630.000000  1972.400000   1203.400000
# 2014-05-05 00:00:00  1887.607143     370.238095  1972.857143    806.428571
# 2014-05-06 00:00:00  1769.638554     332.530120  1969.108434    891.228916
# ...                          ...            ...          ...           ...
# 2014-07-06 00:00:00  1530.000000     680.000000  1948.000000   1334.333333
# 2014-07-07 00:00:00  1825.686747     228.132530  1968.734940    625.843373
# 2014-07-08 00:00:00  1932.149606     293.543307  1974.433071    752.236220
# 2014-07-09 00:00:00  1970.272727     313.966942  1971.669421    725.545455
# 2014-07-10 00:00:00  2006.774194     327.419355  1969.903226    898.290323
#
# [70 rows x 13 columns]

# %%
#correaltion
cor=df.corr()
# Out:
# <ipython-input-21-d767b912e69d>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cor=df.corr()

# %%
cor.style.background_gradient()
# Out:
# <style type="text/css">
# #T_4a99f_row0_col0, #T_4a99f_row1_col1, #T_4a99f_row2_col2, #T_4a99f_row3_col3, #T_4a99f_row4_col4, #T_4a99f_row5_col5, #T_4a99f_row6_col6, #T_4a99f_row7_col7, #T_4a99f_row8_col8, #T_4a99f_row9_col9, #T_4a99f_row10_col10, #T_4a99f_row11_col11, #T_4a99f_row12_col12 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_4a99f_row0_col1, #T_4a99f_row6_col12 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_4a99f_row0_col2, #T_4a99f_row3_col0 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# #T_4a99f_row0_col3 {
#   background-color: #76aad0;
#   color: #f1f1f1;
# }
# #T_4a99f_row0_col4, #T_4a99f_row11_col4 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_4a99f_row0_col5, #T_4a99f_row4_col9 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_4a99f_row0_col6 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_4a99f_row0_col7, #T_4a99f_row10_col12 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_4a99f_row0_col8 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_4a99f_row0_col9 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_4a99f_row0_col10, #T_4a99f_row10_col1 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_4a99f_row0_col11, #T_4a99f_row1_col8 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_4a99f_row0_col12 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_4a99f_row1_col0, #T_4a99f_row4_col12, #T_4a99f_row5_col1, #T_4a99f_row9_col7 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_4a99f_row1_col2, #T_4a99f_row9_col5 {
#   background-color: #358fc0;
#   color: #f1f1f1;
# }
# #T_4a99f_row1_col3 {
#   background-color: #308cbe;
#   color: #f1f1f1;
# }
# #T_4a99f_row1_col4, #T_4a99f_row5_col8, #T_4a99f_row12_col7 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_4a99f_row1_col5, #T_4a99f_row3_col7, #T_4a99f_row7_col2 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_4a99f_row1_col6, #T_4a99f_row8_col4, #T_4a99f_row8_col6 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_4a99f_row1_col7 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_4a99f_row1_col9 {
#   background-color: #549cc7;
#   color: #f1f1f1;
# }
# #T_4a99f_row1_col10 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_4a99f_row1_col11 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_4a99f_row1_col12 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_4a99f_row2_col0 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_4a99f_row2_col1 {
#   background-color: #509ac6;
#   color: #f1f1f1;
# }
# #T_4a99f_row2_col3 {
#   background-color: #0569a5;
#   color: #f1f1f1;
# }
# #T_4a99f_row2_col4 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_4a99f_row2_col5, #T_4a99f_row5_col9 {
#   background-color: #4496c3;
#   color: #f1f1f1;
# }
# #T_4a99f_row2_col6, #T_4a99f_row7_col4 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_4a99f_row2_col7, #T_4a99f_row7_col12 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_4a99f_row2_col8 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_4a99f_row2_col9 {
#   background-color: #0a73b2;
#   color: #f1f1f1;
# }
# #T_4a99f_row2_col10 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_4a99f_row2_col11 {
#   background-color: #3b92c1;
#   color: #f1f1f1;
# }
# #T_4a99f_row2_col12, #T_4a99f_row8_col1, #T_4a99f_row8_col2 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_4a99f_row3_col1, #T_4a99f_row5_col11 {
#   background-color: #3991c1;
#   color: #f1f1f1;
# }
# #T_4a99f_row3_col2 {
#   background-color: #0567a1;
#   color: #f1f1f1;
# }
# #T_4a99f_row3_col4 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_4a99f_row3_col5 {
#   background-color: #79abd0;
#   color: #f1f1f1;
# }
# #T_4a99f_row3_col6 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_4a99f_row3_col8, #T_4a99f_row6_col2, #T_4a99f_row7_col5, #T_4a99f_row7_col11 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_4a99f_row3_col9 {
#   background-color: #045483;
#   color: #f1f1f1;
# }
# #T_4a99f_row3_col10, #T_4a99f_row11_col2 {
#   background-color: #569dc8;
#   color: #f1f1f1;
# }
# #T_4a99f_row3_col11 {
#   background-color: #78abd0;
#   color: #f1f1f1;
# }
# #T_4a99f_row3_col12, #T_4a99f_row12_col8 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_4a99f_row4_col0, #T_4a99f_row11_col10 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_4a99f_row4_col1, #T_4a99f_row9_col12 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_4a99f_row4_col2, #T_4a99f_row6_col11 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_4a99f_row4_col3, #T_4a99f_row7_col9 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_4a99f_row4_col5, #T_4a99f_row6_col9 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_4a99f_row4_col6, #T_4a99f_row6_col4 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_4a99f_row4_col7 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_4a99f_row4_col8, #T_4a99f_row6_col8 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_4a99f_row4_col10, #T_4a99f_row6_col5, #T_4a99f_row9_col4, #T_4a99f_row10_col0 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_4a99f_row4_col11 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_4a99f_row5_col0, #T_4a99f_row9_col10 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_4a99f_row5_col2, #T_4a99f_row9_col11 {
#   background-color: #4e9ac6;
#   color: #f1f1f1;
# }
# #T_4a99f_row5_col3 {
#   background-color: #96b6d7;
#   color: #000000;
# }
# #T_4a99f_row5_col4 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_4a99f_row5_col6, #T_4a99f_row11_col0 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_4a99f_row5_col7 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_4a99f_row5_col10, #T_4a99f_row8_col5, #T_4a99f_row8_col9, #T_4a99f_row8_col11, #T_4a99f_row11_col6, #T_4a99f_row11_col7, #T_4a99f_row11_col8, #T_4a99f_row11_col12, #T_4a99f_row12_col0, #T_4a99f_row12_col1, #T_4a99f_row12_col2, #T_4a99f_row12_col3, #T_4a99f_row12_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_4a99f_row5_col12 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_4a99f_row6_col0, #T_4a99f_row9_col8 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# #T_4a99f_row6_col1, #T_4a99f_row8_col3, #T_4a99f_row10_col4, #T_4a99f_row12_col11 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_4a99f_row6_col3 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_4a99f_row6_col7 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_4a99f_row6_col10 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_4a99f_row7_col0 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_4a99f_row7_col1 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_4a99f_row7_col3, #T_4a99f_row9_col0 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_4a99f_row7_col6 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_4a99f_row7_col8 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_4a99f_row7_col10 {
#   background-color: #84b0d3;
#   color: #f1f1f1;
# }
# #T_4a99f_row8_col0 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_4a99f_row8_col7, #T_4a99f_row10_col6, #T_4a99f_row10_col9 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_4a99f_row8_col10, #T_4a99f_row11_col3 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_4a99f_row8_col12, #T_4a99f_row9_col6 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_4a99f_row9_col1 {
#   background-color: #6da6cd;
#   color: #f1f1f1;
# }
# #T_4a99f_row9_col2 {
#   background-color: #0771b1;
#   color: #f1f1f1;
# }
# #T_4a99f_row9_col3 {
#   background-color: #045687;
#   color: #f1f1f1;
# }
# #T_4a99f_row10_col2 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_4a99f_row10_col3 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_4a99f_row10_col5, #T_4a99f_row12_col9 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_4a99f_row10_col7 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_4a99f_row10_col8 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_4a99f_row10_col11 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_4a99f_row11_col1 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_4a99f_row11_col5 {
#   background-color: #4a98c5;
#   color: #f1f1f1;
# }
# #T_4a99f_row11_col9 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_4a99f_row12_col5, #T_4a99f_ro

# %% [markdown]
# **Visualization**

# %%
import matplotlib.pyplot as plt
city_counts=df['city'].value_counts()
city10=city_counts[0:10]
plt.figure(figsize=(8,8),edgecolor="white")
plt.style.use("fivethirtyeight")
plt.pie(city10.values,labels=city10.index,autopct="%1.1f%%")
plt.show()

# %%
plt.style.use("ggplot")
plt.figure(figsize=(16,6))
plt.bar(df["city"],df["price"])
plt.xlabel("City")
plt.ylabel("Price")
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(16,6))
plt.scatter(df["city"].iloc[0:100],df["bedrooms"].iloc[0:100])
plt.xlabel("City")
plt.ylabel("Bedrooms")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Applying Linear regression fpr prediction**

# %%
#import libraries
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
#splitting X and Y
X = df['sqft_living'].values.reshape(-1, 1)
y = df['price'].values.reshape(-1, 1)

# %%
# Split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# Create a linear regression model
model_lr = LinearRegression()

# %%
# Train the model
model_lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Generate predictions using the trained model
predictions = model_lr.predict(X_test)

info_lr = {'Title': 'House Prices', 'X_label': 'Property Size (sq ft)', 'y_label': 'Price (AUD)'}

# %%
# Create a scatter plot
plt.scatter(X_test, y_test, label='Actual Data')
plt.scatter(X_test, predictions, color='blue', label='Predictions')
plt.xlabel(info_lr['X_label'])
plt.ylabel(info_lr['y_label'])
plt.title(info_lr['Title'])
plt.legend()
plt.show()

# %% [markdown]
# **Applying Random forest**

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
# Create and train the Random Forest Regressor model
model_rf = RandomForestRegressor(n_estimators=100, random_state=42)
model_rf.fit(X_train, y_train)
# Out:
# <ipython-input-55-be557c44c67c>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model_rf.fit(X_train, y_train)
# RandomForestRegressor(random_state=42)

# %%
# Generate predictions on the test set
predictions_rf = model_rf.predict(X_test)

# %%
# Create a scatter plot
plt.scatter(y_test, predictions_rf)
plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")
plt.title("Random Forest Regressor: Actual vs. Predicted Prices")
plt.show()

# %% [markdown]
# **Applying SVR**

# %%
from sklearn.svm import SVR

# %%
# Create and train the Support Vector Regressor model
model_svr = SVR(kernel='linear')
model_svr.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR(kernel='linear')

# %%
# Generate predictions on the test set
predictions_svr = model_svr.predict(X_test)

# %%
# Create a scatter plot
plt.scatter(y_test, predictions_svr)
plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")
plt.title("Support Vector Regressor: Actual vs. Predicted Prices")
plt.show()

# %% [markdown]
# **Gradient Boosting Regressor**

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
# Create and train the Gradient Boosting Regressor model
model_gb = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, random_state=42)
model_gb.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GradientBoostingRegressor(random_state=42)

# %%
# Generate predictions on the test set
predictions_gb = model_gb.predict(X_test)

# %%
# Create a scatter plot
plt.scatter(y_test, predictions_gb)
plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")
plt.title("Gradient Boosting Regressor: Actual vs. Predicted Prices")
plt.show()

# %% [markdown]
# **Evaluation metrics for Linear Regression**

# %%
#MSA
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, predictions)
print("Mean Absolute Error:", mae)
# Out:
# Mean Absolute Error: 180338.8198508743

# %%
#MSE
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, predictions)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 79267882611.9636

# %%
#r2
from sklearn.metrics import r2_score
r2 = r2_score(y_test, predictions)
print("R-squared:", r2)
# Out:
# R-squared: 0.46421948256417844

# %% [markdown]
# **Evaluation metrics for RandomForestRegressor**

# %%
#MSA
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, predictions_rf)
print("Mean Absolute Error:", mae)
# Out:
# Mean Absolute Error: 210794.8296484787

# %%
#MSE
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, predictions_rf)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 130592981058.6902

# %%
#r2
from sklearn.metrics import r2_score
r2 = r2_score(y_test, predictions_rf)
print("R-squared:", r2)
# Out:
# R-squared: 0.11730738024593956

# %% [markdown]
# **Evaluation metrics for SVR**

# %%
#MSA
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, predictions_svr)
print("Mean Absolute Error:", mae)
# Out:
# Mean Absolute Error: 177198.4292998452

# %%
#MSE
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, predictions_svr)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 84148746559.04414

# %%
#r2
from sklearn.metrics import r2_score
r2 = r2_score(y_test, predictions_svr)
print("R-squared:", r2)
# Out:
# R-squared: 0.4312291752047388

# %% [markdown]
# **Evaluation metrics for GradiantBoostingRegressor**

# %%
#MSA
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, predictions_gb)
print("Mean Absolute Error:", mae)
# Out:
# Mean Absolute Error: 195710.68523240194

# %%
#MSE
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, predictions_gb)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 110086473487.67072

# %%
#r2
from sklearn.metrics import r2_score
r2 = r2_score(y_test, predictions_gb)
print("R-squared:", r2)
# Out:
# R-squared: 0.25591316704343103
